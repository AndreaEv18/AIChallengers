# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv("mushroom_data_all.csv")

# %%
train.describe(include='all')
# Out:
#        class_edible cap-shape cap-surface cap-color bruises  odor  \
# count          8124      8124        8124      8124    8124  8124
# unique            2         6           4        10       2     9
# top               e         x           y         n       f     n
# freq           4208      3656        3244      2284    4748  3528
#
#        gill-attachment gill-spacing gill-size gill-color  ...  \
# count             8124         8124      8124       8124  ...
# unique               2            2         2         12  ...
# top                  f            c         b          b  ...
# freq              7914         6812      5612       1728  ...
#
#        stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# count                      8124                   8124                   8124
# unique                        4                      9                      9
# top                           s                      w                      w
# ...

# %%
train.head()
# Out:
#   class_edible cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0            p         x           s         n       t    p               f
# 1            e         x           s         y       t    a               f
# 2            e         b           s         w       t    l               f
# 3            p         x           y         w       t    p               f
# 4            e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
X=train.drop('class_edible',axis=1)
y=train['class_edible']
X.head()
# Out:
#   cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         x           s         n       t    p               f            c
# 1         x           s         y       t    a               f            c
# 2         b           s         w       t    l               f            c
# 3         x           y         w       t    p               f            c
# 4         x           s         g       f    n               f            w
#
#   gill-size gill-color stalk-shape  ... stalk-surface-below-ring  \
# 0         n          k           e  ...                        s
# 1         b          k           e  ...                        s
# 2         b          n           e  ...                        s
# 3         n          n           e  ...                        s
# 4         b          k           t  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

class_mapping={'p': 0, 'e': 1}
train['class_edible'] = train['class_edible'].map(class_mapping)

train.drop("veil-type",axis=1,inplace=True)
train.drop("veil-color",axis=1,inplace=True)

CodificatoreX = LabelEncoder() 
for columns in train.columns:
    train[columns] = CodificatoreX.fit_transform(train[columns])
CodificatoreY=LabelEncoder()
y = CodificatoreY.fit_transform(y)

# %%
train.head()
# Out:
#    class_edible  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0             0          5            2          4        1     6
# 1             1          5            2          9        1     0
# 2             1          0            2          8        1     3
# 3             0          5            3          8        1     6
# 4             1          5            2          3        0     5
#
#    gill-attachment  gill-spacing  gill-size  gill-color  ...  stalk-root  \
# 0                1             0          1           4  ...           3
# 1                1             0          0           4  ...           2
# 2                1             0          0           5  ...           2
# 3                1             0          1           5  ...           3
# 4                1             1          0           4  ...           3
#
#    stalk-surface-above-ring  stalk-surface-below-ring  stalk-color-above-ring  \
# ...

# %%
from sklearn.model_selection import train_test_split

y = train["class_edible"].values   
x = train.drop(["class_edible"], axis=1).values

x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=42,test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier

decisiontree = DecisionTreeClassifier()
decisiontree.fit(x_train, y_train)
y_pred = decisiontree.predict(x_test)

print("ACCURACY: {}%".format(round(decisiontree.score(x_test,y_test)*100,2)))
# Out:
# ACCURACY: 100.0%
